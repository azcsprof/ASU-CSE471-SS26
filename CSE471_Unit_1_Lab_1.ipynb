# %% [markdown]
# <a href="https://colab.research.google.com/github/azcsprof/ASU-CSE471-SS26/blob/Unit-1-Labs/CSE471_Unit_1_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# LAB 1
# SYMBOLIC MEDICAL DIAGNOSIS
#
# Computational Primitives:
# - Symbolic implication
# - Constraint-governed inference
# - Exclusionary reasoning
# ============================================================

# ============================================================
# PURPOSE
# ============================================================

# In this lab, we will investigate how symbolic AI systems:
#
# 1. represent knowledge using symbols,
# 2. apply explicit logical rules,
# 3. derive conclusions mechanically,
# 4. handle competing possibilities,
# 5. and struggle with ambiguity and contradiction.
#
# Unlike statistical AI systems that learn from data,
# this system reasons through explicitly defined structure.
#
# IMPORTANT:
# You are NOT being graded on advanced Python syntax.
#
# You ARE being graded on whether you can explain:
# - what the system does,
# - why it behaves that way,
# - what information it uses,
# - and what limitations it reveals.

# ============================================================
# PART 1 — INITIAL KNOWLEDGE
# ============================================================

# The system stores observations as symbolic facts.
#
# Each symptom is represented as either:
# True  -> symptom is present
# False -> symptom is absent

symptoms = {

    "cough": True,
    "fever": False,
    "sore_throat": True,
    "runny_nose": True,
    "sneezing": True,
    "itchy_eyes": True
}

# ============================================================
# PART 2 — STORE DIAGNOSTIC CONCLUSIONS
# ============================================================

# The system will place inferred diagnoses here.

diagnoses = set()

# ============================================================
# DEMO 1 — SIMPLE SYMBOLIC IMPLICATION
# ============================================================

# ------------------------------------------------------------
# CORE IDEA
# ------------------------------------------------------------
#
# A symbolic rule derives conclusions from explicit conditions.
#
# RULE:
#
# IF:
# cough AND fever AND sore_throat
#
# THEN:
# covid
#
# ------------------------------------------------------------
# PREDICTION TASK
# ------------------------------------------------------------
#
# BEFORE RUNNING:
#
# 1. Will the patient be diagnosed with COVID?
# 2. Which symptoms matter for this rule?
# 3. Which symptoms are ignored?
#
# Write your prediction in a markdown cell or comments.

# ------------------------------------------------------------
# COVID RULE
# ------------------------------------------------------------

if (
    symptoms["cough"]
    and symptoms["fever"]
    and symptoms["sore_throat"]
):

    diagnoses.add("covid")

# ------------------------------------------------------------
# OUTPUT
# ------------------------------------------------------------

print("================================================")
print("Diagnoses After Demo 1")
print("================================================")

print(diagnoses)

# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. Why did the system produce this result?
# 2. What information did the system actually use?
# 3. Does the system understand illness?
# 4. What important medical information is missing?

# ============================================================
# DEMO 2 — COMPETING DIAGNOSES
# ============================================================

# ------------------------------------------------------------
# CORE IDEA
# ------------------------------------------------------------
#
# Symbolic systems can generate multiple conclusions
# simultaneously.
#
# RULE:
#
# IF:
# runny_nose AND sneezing AND itchy_eyes
#
# THEN:
# allergies
#
# ------------------------------------------------------------
# PREDICTION TASK
# ------------------------------------------------------------
#
# BEFORE RUNNING:
#
# 1. Will the system now infer allergies?
# 2. Can multiple diagnoses exist simultaneously?
# 3. Does the system know which diagnosis is "best"?

# ------------------------------------------------------------
# ALLERGY RULE
# ------------------------------------------------------------

# TODO:
# Complete the missing conditions below.

if (

    symptoms["runny_nose"]
    and symptoms["sneezing"]
    and __________________________

):

    diagnoses.add("allergies")

# ------------------------------------------------------------
# OUTPUT
# ------------------------------------------------------------

print()
print("================================================")
print("Diagnoses After Demo 2")
print("================================================")

print(diagnoses)

# ------------------------------------------------------------
# MODIFICATION TASK
# ------------------------------------------------------------
#
# Add a NEW rule for:
#
# common cold
#
# Suggested symptoms:
# - cough
# - runny_nose
# - sore_throat
#
# Then rerun the system.
#
# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. Did multiple diagnoses appear?
# 2. Why does the system struggle with competing conclusions?
# 3. What mechanism is missing?
#
# KEY IDEA:
#
# Rule systems can generate possibilities,
# but they do not automatically know which
# possibility is better.

# ============================================================
# DEMO 3 — EXCLUSIONARY REASONING
# ============================================================

# ------------------------------------------------------------
# CORE IDEA
# ------------------------------------------------------------
#
# Rules can also ELIMINATE possibilities.
#
# RULE:
#
# IF:
# allergies
#
# THEN:
# NOT covid
#
# This reduces the space of possible conclusions.
#
# ------------------------------------------------------------
# PREDICTION TASK
# ------------------------------------------------------------
#
# BEFORE RUNNING:
#
# 1. What should happen to the COVID diagnosis?
# 2. Why is this different from simply adding
# another diagnosis?

# ------------------------------------------------------------
# EXCLUSIONARY RULE
# ------------------------------------------------------------

if "allergies" in diagnoses:

    # TODO:
    # Remove "covid" from the diagnoses set.

    ________________________________

# ------------------------------------------------------------
# OUTPUT
# ------------------------------------------------------------

print()
print("================================================")
print("Diagnoses After Demo 3")
print("================================================")

print(diagnoses)

# ------------------------------------------------------------
# MODIFICATION TASK
# ------------------------------------------------------------
#
# Create a contradiction.
#
# Example:
#
# IF allergies THEN NOT covid
# IF fever THEN covid
#
# Then:
#
# 1. Change fever to True
# 2. Rerun the system
#
# Observe:
# - what changes,
# - what conflicts,
# - and what the system cannot resolve.

# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. What happens when rules conflict?
# 2. Does the system know which rule should dominate?
# 3. Why do contradictions become difficult
# in symbolic systems?
#
# KEY IDEA:
#
# Symbolic systems often require additional
# mechanisms to resolve conflicting rules.

# ============================================================
# FINAL SYNTHESIS
# ============================================================

# Write 5–7 sentences addressing:
#
# How do symbolic AI systems derive conclusions,
# and why do rigid rule systems struggle with
# ambiguity and conflict?
#
# REQUIRED IDEAS:
# - symbolic implication
# - rule-based inference
# - competing diagnoses
# - exclusionary reasoning
# - system limitations

# ============================================================
# OPTIONAL EXTENSION
# ============================================================

# Instead of:
#
# diagnoses.add("covid")
#
# try:
#
# covid_score += 1
#
# Reflection:
#
# How does this begin to resemble probabilistic
# reasoning instead of purely symbolic reasoning?
