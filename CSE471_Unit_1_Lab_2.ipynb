# %% [markdown]
# <a href="https://colab.research.google.com/github/azcsprof/ASU-CSE471-SS26/blob/Unit-1-Labs/CSE471_Unit_1_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# UNIT 1 LAB 2
# RELATIONAL REASONING AND STRUCTURED KNOWLEDGE
#
# Computational Primitives:
# - Relational abstraction
# - Inference propagation
# - Structured representation
# ============================================================

# ============================================================
# PURPOSE
# ============================================================

# In this lab, we will investigate how intelligent systems:
#
# 1. represent relationships between objects,
# 2. reason across structured connections,
# 3. derive conclusions that were never directly stated,
# 4. propagate inference through relational chains,
# 5. and struggle with scaling relational complexity.
#
# Unlike propositional systems that reason about
# isolated true/false statements, relational systems
# reason about connected structures.
#
# IMPORTANT:
# You are NOT being graded on advanced Python syntax.
#
# You ARE being graded on whether you can explain:
# - what the system is doing,
# - why the inferences occur,
# - what relationships matter,
# - and what limitations emerge.

# ============================================================
# PART 1 — INITIAL KNOWLEDGE BASE
# ============================================================

# ------------------------------------------------------------
# RELATIONSHIP:
#
# ("kim", "room_101")
#
# means:
#
# Kim is inside room_101
# ------------------------------------------------------------

in_location = {

    ("kim", "room_101")
}

# ------------------------------------------------------------
# RELATIONSHIP:
#
# ("room_101", "cs_building")
#
# means:
#
# room_101 is part of cs_building
# ------------------------------------------------------------

part_of = {

    ("room_101", "cs_building")
}

# ============================================================
# PART 2 — STORE INFERRED RELATIONSHIPS
# ============================================================

# The system will place newly inferred
# relationships here.

inferred_locations = set()

# ============================================================
# DEMO 1 — INDIRECT RELATIONAL INFERENCE
# ============================================================

# ------------------------------------------------------------
# CORE IDEA
# ------------------------------------------------------------
#
# The system can derive relationships that
# were never directly stored.
#
# RULE:
#
# IF:
# X is in Z
# AND Z is part of Y
#
# THEN:
# X is in Y
#
# ------------------------------------------------------------
# PREDICTION TASK
# ------------------------------------------------------------
#
# BEFORE RUNNING:
#
# 1. What relationship should the system infer?
# 2. Why?
# 3. Which relationships combine to produce
# the new conclusion?
#
# Write your prediction in markdown or comments.

# ------------------------------------------------------------
# RELATIONAL INFERENCE
# ------------------------------------------------------------

for person, location in in_location:

    for sublocation, larger_location in part_of:

        # ----------------------------------------------------
        # TODO:
        #
        # If the current location matches the
        # sublocation,
        #
        # infer:
        #
        # (person, larger_location)
        #
        # ----------------------------------------------------

        if ________________________________:

            inferred_locations.add(

                (person, larger_location)

            )

# ------------------------------------------------------------
# OUTPUT
# ------------------------------------------------------------

print("================================================")
print("Inferred Relationships After Demo 1")
print("================================================")

print(inferred_locations)

# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. What new relationship was inferred?
# 2. Was this relationship directly stored?
# 3. Why is relational reasoning more powerful
# than isolated true/false facts?
# 4. What role does structure play in the inference?

# ============================================================
# DEMO 2 — GENERALIZATION ACROSS INDIVIDUALS
# ============================================================

# ------------------------------------------------------------
# CORE IDEA
# ------------------------------------------------------------
#
# Relational rules can generalize across
# many individuals automatically.
#
# The same rule should work for:
# - Kim
# - Alex
# - Jordan
# - or any other individual.
#
# ------------------------------------------------------------
# PREDICTION TASK
# ------------------------------------------------------------
#
# BEFORE RUNNING:
#
# 1. What new relationships should appear?
# 2. Why does the SAME rule apply to
# multiple individuals?

# ------------------------------------------------------------
# ADD NEW RELATIONSHIPS
# ------------------------------------------------------------

in_location.add(

    ("alex", "room_201")

)

part_of.add(

    ("room_201", "engineering_building")

)

# ------------------------------------------------------------
# RESET STORAGE
# ------------------------------------------------------------

inferred_locations = set()

# ------------------------------------------------------------
# RERUN INFERENCE
# ------------------------------------------------------------

for person, location in in_location:

    for sublocation, larger_location in part_of:

        if location == sublocation:

            inferred_locations.add(

                (person, larger_location)

            )

# ------------------------------------------------------------
# OUTPUT
# ------------------------------------------------------------

print()
print("================================================")
print("Inferred Relationships After Demo 2")
print("================================================")

print(inferred_locations)

# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. Why does the rule work for multiple people?
# 2. What makes this different from propositional logic?
# 3. How does relational abstraction support
# generalized reasoning?
#
# KEY IDEA:
#
# Relational rules generalize across many
# entities without rewriting the rule itself.

# ============================================================
# DEMO 3 — MULTI-STEP INFERENCE CHAINS
# ============================================================

# ------------------------------------------------------------
# CORE IDEA
# ------------------------------------------------------------
#
# Relational inference can propagate through
# multiple levels of structure.
#
# Example:
#
# room_201 → engineering_building
# engineering_building → science_complex
#
# Therefore:
#
# alex → science_complex
#
# ------------------------------------------------------------
# PREDICTION TASK
# ------------------------------------------------------------
#
# BEFORE RUNNING:
#
# 1. What new inference should appear?
# 2. Why does this require multiple reasoning steps?
# 3. What information is propagating through the system?

# ------------------------------------------------------------
# ADD NEW STRUCTURAL RELATIONSHIP
# ------------------------------------------------------------

part_of.add(

    ("engineering_building", "science_complex")

)

# ------------------------------------------------------------
# STORAGE
# ------------------------------------------------------------

expanded_inference = set()

# ------------------------------------------------------------
# MULTI-STEP INFERENCE
# ------------------------------------------------------------

for person, location in in_location:

    for sublocation, larger_location in part_of:

        if location == sublocation:

            expanded_inference.add(

                (person, larger_location)

            )

            # ------------------------------------------------
            # SECOND-LEVEL SEARCH
            # ------------------------------------------------

            for sub2, larger2 in part_of:

                # --------------------------------------------
                # TODO:
                #
                # If larger_location matches sub2,
                # infer:
                #
                # (person, larger2)
                #
                # --------------------------------------------

                if ________________________________:

                    expanded_inference.add(

                        (person, larger2)

                    )

# ------------------------------------------------------------
# OUTPUT
# ------------------------------------------------------------

print()
print("================================================")
print("Inferred Relationships After Demo 3")
print("================================================")

print(expanded_inference)

# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. What new inference appeared?
# 2. Why was this relationship never directly stored?
# 3. How do inference chains create more abstract knowledge?
# 4. Why does relational reasoning become more
# computationally expensive as structure grows?
#
# KEY IDEA:
#
# Relational systems can derive increasingly
# abstract conclusions through inference propagation.

# ============================================================
# MODIFICATION TASK — CONTROLLED FAILURE
# ============================================================

# ------------------------------------------------------------
# TASK:
#
# Create a problematic relationship.
#
# Examples:
#
# ("science_complex", "room_201")
#
# or:
#
# circular structures
#
# Observe:
# - what propagates,
# - what becomes confusing,
# - and what kinds of errors emerge.

# ------------------------------------------------------------
# REFLECTION QUESTIONS
# ------------------------------------------------------------
#
# 1. What problems appeared?
# 2. Why can incorrect relationships propagate?
# 3. Why are large relational systems difficult to debug?
# 4. What happens when relational chains become large?
#
# KEY IDEA:
#
# Relational systems are powerful,
# but inference propagation can also
# spread incorrect conclusions.

# ============================================================
# FINAL SYNTHESIS
# ============================================================

# Write 5–7 sentences addressing:
#
# How do relational AI systems derive new knowledge
# from structured relationships, and why does
# relational reasoning become increasingly difficult
# at larger scales?
#
# REQUIRED IDEAS:
# - relational abstraction
# - generalized rules
# - inference propagation
# - indirect inference
# - relational scaling
# - system limitations

# ============================================================
# OPTIONAL EXTENSION
# ============================================================

# Add:
#
# ("science_complex", "asu_campus")
#
# Then extend the system so inference can continue
# propagating upward through even more levels.
#
# Reflection:
#
# What happens as relational chains become deeper?
#
# How does this resemble knowledge graphs,
# semantic systems, or large symbolic AI systems?
